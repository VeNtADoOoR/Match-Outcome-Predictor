# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.ingest import load_data, validate_games, create_target


data = load_data()
games = validate_games(data['games'])
games = create_target(games)

print(games[['date', 'home_club_name', 'away_club_name', 
             'home_club_goals', 'away_club_goals', 'outcome']].head(10))
# Out:
# Loaded games: 88807 rows, 23 columns
# Missing values:
# home_club_position        25314
# away_club_position        25314
# home_club_manager_name      844
# away_club_manager_name      844
# stadium                     242
# attendance                10808
# referee                     678
# home_club_formation        8195
# away_club_formation        8069
# home_club_name               86
# away_club_name               36
# dtype: int64
#
# Loaded clubs: 796 rows, 17 columns
# Missing values:
# total_market_value       796
# average_age               38
# foreigners_percentage     58
# coach_name               706
# dtype: int64
#
#
# Outcome distribution:
# outcome
# H    0.451
# A    0.332
# D    0.217
# Name: proportion, dtype: float64
#         date         home_club_name  away_club_name  home_club_goals  \
# 0 2006-06-09                Germany      Costa Rica                4
# 1 2006-06-09                 Poland         Ecuador                0
# ...
